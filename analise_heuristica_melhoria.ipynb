# %% [markdown]
# N = 40
#
# ótimo relaxado = 493.36
#
# heuristica_construtiva
# NN = 617.43
# CI = 578.67
# FI = 510.58
#
# heuristica_melhoria_2_20
# NN = 493.37
# CI = 523.41
# FI = 508.60 (apenas 2 melhorias)
#
# heuristica_melhoria_3_20
# NN = 540.24 (apenas 2 melhorias)
# CI = 500.28 (apenas 2 melhorias)
# FI = 503.88 (apenas 1 melhoria)
#
# ----Perturbação v2------
# heuristica_melhoria_2_20
# NN = 507.11
# CI = 497.31
# FI = 510.58 (nenhuma melhoria)
#
# heuristica_melhoria_3_20
# NN = 554.01
# CI = 508.02 ( 1 melhoria)
# FI = 503.88 (1 melhoria)
